# %% [markdown]
# ### 1. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2 retornando o resultado e o apresente.

# %%
def multiplicar():
    numero = int(input('Digite um valor: '))
    resultado = numero * 2
    return resultado

def main():
    print('entrei na main')
    # Primeira forma de chamar a função com retorno
    r = multiplicar()
    print('Resultado com uma variável: ',r)

    # Segunda forma de chamar uma função com retorno
    #print('Resultado com uma variável:',multiplicar())

main()
# Out:
# entrei na main
# Digite um valor: 5
# Resultado com uma variável: 10

# %% [markdown]
# ### 2. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método para subtrair dois números, retornar o resultado e o apresentando.

# %%
def subtrair():
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    return num1 - num2

def main():
    print(subtrair())

main()
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 3
# 1

# %% [markdown]
# ### 3. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia a base e a altura de um triângulo e retorne/apresente sua área A = (base x altura)/2.

# %%
def calculo_area():
    altura = float(input("Digite o valor da altura: "))
    base = float(input("Digite o valor da base: "))
    return (base*altura) / 2

def main():
    print(calculo_area())

main()
# Out:
# Digite o valor da altura: 30
# Digite o valor da base: 20
# 300.0

# %% [markdown]
# ### 4. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método que leia o lado de um quadrado e retorne sua área, area = lado².

# %%
def area_quadrado():
    lado = float(input("Digite o lado do quadrado: "))
    return lado ** 2

def main():
    print("Area do quadrado:"area_quadrado())

main()
# Out:
# Digite o lado do quadrado: 2.5
# 6.25

# %% [markdown]
# ###5. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne mostrando a str/string ‘É par’ ou se ‘É ímpar’.

# %%
def verificar_par_impar():
    numero = int(input("Digite o número: "))
    if numero % 2 == 0:
        return "É par"
    else:
        return "É impar"

def main():
    print(verificar_par_impar())

main()
# Out:
# Digite o número: 4
# É par

# %%
#utilizando expressão condicional/operador ternário
def verificar_par_impar():
    numero = int(input("Digite o número: "))
    return "É par!" if numero % 2 == 0 else "É ímpar!"

def main():
    print(verificar_par_impar())

main()
# Out:
# Digite o número: 3
# É ímpar!

# %% [markdown]
# ###6. (Função com retorno sem parâmetro) Faça um programa contendo uma função/método  que verifique se um número é par, retorne/mostre o valor bool **True** para par e **False** para ímpar.

# %%
def verificar_par_impar():
    num = int(input("Digite o número: "))
    return True if num % 2 == 0 else False

def main():
    print('É par?',verificar_par_impar())

main()
# Out:
# Digite o número: 2
# É par? True

# %% [markdown]
# ### 7. (Função com retorno sem parâmetro) Faça uma função/método que leia e armazene 5 elementos inteiros no vetor A, deverá ser gerado um vetor B, de mesmo tamanho, que armazenará o fatorial de cada elemento de A. Não use função pronta de cálculo de fatorial. Retorne/apresente o vetor B.

# %%
# Exemplo:
# A = [5  ,4 ,3,2,1]
# B = [120,24,6,2,1]

# %%
def fatorial():
    vetor_a, vetor_b = [], []
    for i in range(5):
        vetor_a.append(int(input("Digite um número: ")))
    print("A =",vetor_a)
    for i in range(len(vetor_a)):
        count = 1
        resultado = 1
        while count <= vetor_a[i]:
            resultado *= count
            count += 1
        vetor_b.append(resultado)
    return vetor_b


def main():
    print("B =",fatorial())

main()
# Out:
# Digite um número: 5
# Digite um número: 4
# Digite um número: 3
# Digite um número: 2
# Digite um número: 1
# A = [5, 4, 3, 2, 1]
# B = [120, 24, 6, 2, 1]

# %% [markdown]
# ### 8. (Função com retorno sem parâmetro) Faça uma função/método retorne um vetor com os três primeiros números perfeitos. Sabe-se que um número é perfeito quando é igual a soma de seus divisores (exceto ele mesmo).
# Exemplo: os divisores de 6 são 1, 2 e 3, e 1 + 2 + 3 = 6, logo 6 é perfeito. Não use função pronta.
#
# 1º número perfeito: 6
#
# 2º número perfeito: 28
#
# 3º número perfeito: 496

# %%
# número 1 não é perfeito
# ...
# número 4 não é perfeito, exemplo: 4 % 1 == 0, 4 % 2 == 0, 4 % 3 != 0, a soma
# resulta em 2
# ...
# número 6 é perfeito  6 % 1 == 0, 6 % 2 == 0, 6 % 3 == 0, 6 % 4 != 0, 6 % 5 != 0
# quando é perfeito a soma de seus divisores da o mesmo valor de número que é 6

#for n in range (1, 497)
#    div outro laço de repetição 1 até n:
#        desenvolva a lógica aqui

# %%
vet_numeros = []

def verifica_num_perfeito():
    for n in range(1,497):
        soma = 0
        for i in range (1, n):
            if n % i == 0:
                soma += i
        if n == soma:
            vet_numeros.append(n)
    return vet_numeros

def main():
    print(verifica_num_perfeito())

main()
# Out:
# [6, 28, 496]

# %% [markdown]
# ### 9. (Função com retorno sem parâmetro) Foi realizada uma pesquisa sobre algumas características físicas de cinco habitantes de uma região. Foram coletados os seguintes dados de cada habitante: idade, sexo (M - masculino ou F - feminino), cor dos olhos (A - azuis ou C - castanhos), cor dos cabelos (L - louros, P - pretos ou C - castanhos).
#
# 1.   Faça uma função/método que leia esses dados, armazenando-os em vetores (listas);
# 2.   Faça uma função/método que determine e devolva a função principal a média de idades das pessoas com olhos castanhos e cabelos pretos;
# 3. Faça uma função/método que determine e devolva a função principal a maior idade entre os habitantes;
# 4.  Faça uma função/método que determine e devolva a função principal a quantidade de indivíduos do sexo feminino com idade entre 18 e 35 anos(inclusive) e que tenham olhos azuis e cabelos louros.

# %%
# Declarar os vetores antes de qualquer programação, indica que
# que estas variáveis serão globais a todo o restante do programa
# e das funções
#idade = []
#sexo = []
#olho = []
#cabelo = []

#def cadastrar():
#...
#...
#def main():

#main()

# %%
idade, sexo, olho, cabelo = [], [], [], []

def cadastrar():
    for i in range(5):
        idade.append(int(input(f"Digite a idade do participante {i+1}: ")))
        sexo.append(input(f"Digite o sexo do participante {i+1}\nM - Masculino\nF - Feminino: "))
        olho.append(input(f"Digite a cor do olho do participante {i+1}\nA - Azuis\nC - Castanhos: "))
        cabelo.append(input(f"Digite a cor do cabelo do participante {i+1}\nL - Louros\nP - Pretos\nC - Castanhos: "))

def media_idades():
    soma_idade, qtde_pessoas = 0, 0
    for i in range(len(idade)):
        if olho[i] == "C" and cabelo[i] == "P":
            soma_idade += idade[i]
            qtde_pessoas += 1
    return soma_idade / qtde_pessoas

def maior_idade():
    m_idade = 0
    for i in range(len(idade)):
        if i == 0:
            m_idade = idade[i]
        elif idade[i] > m_idade:
            m_idade = idade[i]
    return m_idade

def fem_azul_louro():
    qtde_pessoas = 0
    for i in range(len(idade)):
        if sexo[i] == "F" and idade[i] > 18 and idade[i] <= 35 and olho[i] == "A" and cabelo[i] == "L":
            qtde_pessoas += 1
    return qtde_pessoas

def main():
    cadastrar()
    media_idade = media_idades()
    print(f"Média de Idade das pessoas com olhos castanhos e cabelos pretos: {media_idade}")
    m_idade = maior_idade()
    print(f"A maior idade entre os habitantes é: {m_idade}")
    publico_fem = fem_azul_louro()
    print(f"Quantidade de pessoas do sexo feminino que tem idade entre 18 e 35 anos e possui cabelos loiros e olhos azuis: {publico_fem}")

main()
# Out:
# Digite a idade do participante 1: 20
# Digite o sexo do participante 1
# M - Masculino
# F - Feminino: F
# Digite a cor do olho do participante 1
# A - Azuis
# C - Castanhos: A
# Digite a cor do cabelo do participante 1
# L - Louros
# P - Pretos
# C - Castanhos: L
# Digite a idade do participante 2: 30
# Digite o sexo do participante 2
# M - Masculino
# F - Feminino: M
# Digite a cor do olho do participante 2
# A - Azuis
# C - Castanhos: C
# Digite a cor do cabelo do participante 2
# L - Louros
# P - Pretos
# C - Castanhos: P
# Digite a idade do participante 3: 40
# Digite o sexo do participante 3
# M - Masculino
# F - Feminino: F
# Digite a cor do olho do participante 3
# A - Azuis
# C - Castanhos: A
# Digite a cor do cabelo do participante 3
# L - Louros
# P - Pretos
# C - Castanhos: L
# Digite a idade do participante 4: 23
# Digite o sexo do participante 4
# M - Masculino
# F - Feminino: M
# Digite a cor do olho do participante 4
# A - Azuis
# C - Castanhos: C
# Digite a cor do cabelo do participante 4
# L - Louros
# P - Pretos
# C - Castanhos: P
# Digite a idade do participante 5: 55
# Digite o sexo do participante 5
# M - Masculino
# F - Feminino: F
# Digite a cor do olho do participante 5
# A - Azuis
# C - Castanhos: C
# Digite a cor do cabelo do participante 5
# L - Louros
# P - Pretos
# C - Castanhos: C
# Média de Idade das pessoas com olhos castanhos e cabelos pretos: 26.5
# A maior idade entre os habitantes é: 55
# Quantidade de pessoas do sexo feminino que tem idade entre 18 e 35 anos e possui cabelos loiros e olhos azuis: 1
