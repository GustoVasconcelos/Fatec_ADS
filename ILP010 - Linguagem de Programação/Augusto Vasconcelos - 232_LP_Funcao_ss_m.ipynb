# %%
#aula formatação de strings
#---------------------------------
#exemplo 1
#nome = "Guido Van Rossum"
#nome2 = "Augusto Navarro"
#idade = 68
#idade2 = 34
#grana = 10541.7862
#grana2 = 10541345.7862
#print(f'{nome} tem {idade} anos e R$ {grana:.2f}')
#print('%-17s tem %i anos e R$ %12.2f' %(nome, idade, grana))
#print('%-17s tem %i anos e R$ %12.2f' %(nome2, idade2, grana2))

#exemplo feito por mim utilizando vetores
#nome_tabela = [['Guido Van Rossum','Augusto Navarro']]
#idade_tabela = [[68, 34]]
#grana_tabela = [[10541.7862,10541345.7862]]
#for i in range(1):
#    for j in range(2):
#        print('%-17s tem %i anos e R$ %12.2f' %(nome_tabela[i][j], idade_tabela[i][j], grana_tabela[i][j]))

#exemplo de centralização de texto
#print('{0:^30}.'.format(nome))

#exemplo adição de strings
#nome = 'Augusto'
#sobrenome = 'Navarro'
#print(nome + ' ' + sobrenome)

#exemplo multiplicação de strings
#print('.'*50)
# Out:
# Guido Van Rossum tem 68 anos e R$ 10541.79
# Guido Van Rossum  tem 68 anos e R$     10541.79
# Augusto Navarro   tem 34 anos e R$  10541345.79

# %% [markdown]
# ### 1.0 (Função sem retorno sem parâmetro) Faça um programa contendo uma função/método que leia um número e o multiplique por 2. Apresente o resultado. EXEMPLO.

# %%
def multiplicar(): # definição da função
    numero = int(input("Digite o número: "))
    resultado = numero * 2
    print("O resultado é", resultado)

multiplicar() #chamada da função
# Out:
# Digite o número: 9
# O resultado é 18

# %%
def multiplicar(): # definição da função
    numero = int(input("Digite o número: "))
    resultado = numero * 2
    print("O resultado é", resultado)

def main(): # É uma boa prática implementar a função main
    multiplicar()

main()
# Out:
# Digite o número: 6
# O resultado é 12

# %% [markdown]
# ### 1.1 (Função sem retorno sem parâmetro) Faça um programa contendo uma função/método que apresente o valor 1 se o número digitado for positivo e 0 se for negativo.

# %%
def apresentar_numero():
    valor = float(input("Digite o número: "))
    if valor > 0:
        print('1')
    else:
        print('0')

def main():
    apresentar_numero()

main()
# Out:
# Digite o número: 1
# 1

# %% [markdown]
# ### 2. (Função sem retorno sem parâmetro) Faça uma função/método que leia dois valores positivos e apresente a soma dos N números existentes entre eles (inclusive).
#     Exemplo:
#         a = 2
#         b = 8
#         2 + 3 + 4 + 5 + 6 + 7 + 8
#         soma = 35

# %%
def somar():
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    soma = 0
    while num1 <= num2:
        if soma < 0 or num1 < num2:
            print(f'{num1} +', end=' ')
        else:
            print(f'{num1} ', end=' ')
        soma += num1
        num1 += 1
    print(f'= {soma}')

def main():
    somar()

main()
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 8
# 2 + 3 + 4 + 5 + 6 + 7 + 8  = 35

# %%
# mesmo exercicio anterior porem usando for e fazendo validaçao de qual numero e maior/menor
def somar():
    num1 = int(input("Digite o primeiro número: "))
    num2 = int(input("Digite o segundo número: "))
    soma = 0
    if num1 > num2:
        i = num1
        num1 = num2
        num2 = i
    for num1 in range(num1, num2+1):
        if soma < 0 or num1 < num2:
            print(f'{num1} +', end=' ')
        else:
            print(f'{num1} ', end=' ')
        soma += num1
    print(f'= {soma}')

def main():
    somar()

main()
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 8
# 2 + 3 + 4 + 5 + 6 + 7 + 8  = 35

# %% [markdown]
# ### 3. (Função sem retorno sem parâmetro) Faça uma função/método que receba três números inteiros *a*, *b*, *c* que sejam divisíveis por ***a***. Os valores *b* e *c* representam o intervalo da estrutura de repetição. Apresente a quantidade e os números divisíveis. Não pode usar vetor e função pronta da linguagem Python.
#     Exemplo:
#         a = 5
#         b = 1
#         c = 10
#         1 % a
#         2 % a
#         3 % a
#         4 % a
#         5 % a este valor é divisível
#         6 % a
#         7
#         8
#         9
#         10 % a este valor é divisível
#         qtde = 2

# %%
def divisiveis():
    divisor = int(input("Digite o número que será usado como divisor: "))
    num1 = int(input("Digite o primeiro número do intervalo a ser calculado: "))
    num2 = int(input("Digite o segundo número do intervalo a ser calculado: "))
    qntde_divisiveis = 0
    for num1 in range(num1, num2 + 1):
        if num1 % divisor == 0:
            print(f"{num1} % {divisor} este valor é divisivel")
            qntde_divisiveis += 1
        else:
            print(f"{num1} % {divisor}")
    print(f"Quantidade de números divisiveis: {qntde_divisiveis}")

def main():
    divisiveis()

main()
# Out:
# Digite o número que será usado como divisor: 5
# Digite o primeiro número do intervalo a ser calculado: 1
# Digite o segundo número do intervalo a ser calculado: 10
# 1 % 5
# 2 % 5
# 3 % 5
# 4 % 5
# 5 % 5 este valor é divisivel
# 6 % 5
# 7 % 5
# 8 % 5
# 9 % 5
# 10 % 5 este valor é divisivel
# Quantidade de números divisiveis: 2

# %%
# mesmo exercicio que o anterior, porem fazendo validaçao de qual numero digitado é maior/menor
def divisiveis():
    divisor = int(input("Digite o número que será usado como divisor: "))
    num1 = int(input("Digite o primeiro número do intervalo a ser calculado: "))
    num2 = int(input("Digite o segundo número do intervalo a ser calculado: "))
    qntde_divisiveis = 0
    if num1 > num2:
        i = num1
        num1 = num2
        num2 = i
    for num1 in range(num1, num2 + 1):
        if num1 % divisor == 0:
            print(f"{num1} % {divisor} este valor é divisivel")
            qntde_divisiveis += 1
        else:
            print(f"{num1} % {divisor}")
    print(f"Quantidade de números divisiveis: {qntde_divisiveis}")

def main():
    divisiveis()

main()
# Out:
# Digite o número que será usado como divisor: 5
# Digite o primeiro número do intervalo a ser calculado: 10
# Digite o segundo número do intervalo a ser calculado: 1
# 1 % 5
# 2 % 5
# 3 % 5
# 4 % 5
# 5 % 5 este valor é divisivel
# 6 % 5
# 7 % 5
# 8 % 5
# 9 % 5
# 10 % 5 este valor é divisivel
# Quantidade de números divisiveis: 2

# %% [markdown]
# ### 4. (Função sem retorno sem parâmetro) Faça uma função/método que leia um único valor representado em segundos, converta-o e apresente o resultado em horas, minutos e segundos.
#     h = segundos / 3600
#     r = resto(segundos / 3600)
#     m = r / 60
#     s = resto(r / 60)
#     Observação 1: resto de uma divisão em Python %.
#     Observação 2: a hora, o minuto e o segundo devem ser apresentados como números inteiros.

# %%
def convert_seg():
    segundos = int(input("Digite a quantidade de segundos: "))
    hora = segundos / 3600
    resto = segundos % 3600
    minutos = resto / 60
    segundos = resto % 60
    print(f"{int(hora)}:{int(minutos)}:{int(segundos)}")

def main():
    convert_seg()

main()
# Out:
# Digite a quantidade de segundos: 12000
# 3:20:0

# %% [markdown]
# ### 5. (Função sem retorno sem parâmetro) Faça uma função/método que receba o preço antigo e atual de um produto, determine o percentual de acréscimo entre esses valores e apresente-o.
#     r = (100 * preco_novo - 100 * preco_antigo) / preco_antigo

# %%
def percentual():
    preco_antigo = float(input("Digite o preço antigo: "))
    preco_novo = float(input("Digite o preço novo: "))
    porcentagem = (100 * preco_novo - 100 * preco_antigo) / preco_antigo
    print(f"O percentual de acréscimo foi de {porcentagem:.2f}%")

def main():
    percentual()

main()
# Out:
# Digite o preço antigo: 2
# Digite o preço novo: 3
# O percentual de acréscimo foi de 50.00%

# %% [markdown]
# ### 6. (Função sem retorno sem parâmetro) Faça uma função/método que leia um valor inteiro entre 1 e 9 e mostre a seguinte tabela de **multiplicação**
# Neste exemplo foi escolhido o número 9.
#
#     1
#     2     4
#     3     6     9
#     4     8    12    16
#     5    10    15    20    25
#     6    12    18    24    30    36
#     7    14    21    28    35    42    49
#     8    16    24    32    40    48    56    64
#     9    18    27    36    45    54    63    72    81
#     for i = 1 até n
#        for j = 1 até i
#
#     Observação: configure o print para não pular linha, use o parâmetro end.

# %%
def multiplicacao():
    n = int(input("Digite o número entre 1 e 9: "))
    for i in range(1, n+1):
        for j in range(1, i+1):
            print(f"{i*j}", end = '\t')
        print()

def main():
    multiplicacao()

main()
# Out:
# Digite o número entre 1 e 9: 9
# 1
# 2	4
# 3	6	9
# 4	8	12	16
# 5	10	15	20	25
# 6	12	18	24	30	36
# 7	14	21	28	35	42	49
# 8	16	24	32	40	48	56	64
# 9	18	27	36	45	54	63	72	81

# %% [markdown]
# ### 7. (Função sem retorno sem parâmetro) Faça uma função/método que leia três notas de um aluno e uma letra, se a letra for igual a *A*, deverá calcular a média aritimética das notas dos alunos, se for *P*, deverá calcular a média ponderada, com pesos 5, 3 e 2. A média deve ser mostrada ao final.
# N1, N2 e N3 são notas.
#
# P1, P2 e P3 são pesos.
#
# Média ponderada = (N1 * P1 + N2 * P2 + N3 * P3 ) / (P1 + P2 + P3)

# %%
def media_aluno():
    p1, p2, p3 = 5, 3, 2
    n1 = float(input("Digite a primeira nota do aluno: "))
    n2 = float(input("Digite a segunda nota do aluno: "))
    n3 = float(input("Digite a terceira nota do aluno: "))
    escolha = input('Escolha "A" para calcular a média aritmetica ou "P" para calcular a média ponderada ( com pesos) do aluno: ')
    if escolha == "A" or escolha == "P":
        if escolha == "A":
            media = (n1 + n2 + n3) / 3
            print(f"A média do aluno é {media:.2f}")
        elif escolha == "P":
            media = (n1*p1+n2*p2+n3*p3)/(p1+p2+p3)
            print(f"A média ponderada do aluno é {media:.2f}")

def main():
    media_aluno()

main()
# Out:
# Digite a primeira nota do aluno: 10
# Digite a segunda nota do aluno: 9
# Digite a terceira nota do aluno: 8
# Escolha "A" para calcular a média aritmetica ou "P" para calcular a média ponderada ( com pesos) do aluno: P
# A média ponderada do aluno é 9.30

# %% [markdown]
# ### 8. (Função sem retorno sem parâmetro) Faça uma função/método que leia uma hora de início e de término de um jogo, ambas divididas em dois valores distintos: hora e minuto. Deverá ser apresentado a duração expressa em minutos, considerando que o tempo máximo de duração de um jogo é de 24 horas e que ele pode começar em um dia e terminar no outro.
#     se m_f < m_i
#         m_f = m_f + 60
#         h_f = h_f - 1
#     se h_f < h_i
#         h_f = h_f + 24
#     tot_m = m_f - m_i
#     tot_h = h_f - h_i
#     total = tot_h * 60 + tot_m

# %%
def tempoJogo():
    hora_i = int(input("Digite a hora do primeiro horário: "))
    minuto_i = int(input("Digite os minutos do primeiro horário: "))
    hora_f = int(input("Digite a hora do segundo horário: "))
    minuto_f = int(input("Digite os minutos do segundo horário: "))
    if minuto_f < minuto_i:
        minuto_f = minuto_f + 60
        hora_f = hora_f - 1
    if hora_f < hora_i:
        hora_f = hora_f + 24
    total_m = minuto_f - minuto_i
    total_h = hora_f - hora_i
    total = total_h * 60 + total_m
    print(f'O jogo teve no total {total} minutos.')

def main():
    tempoJogo()

main()
# Out:
# Digite a hora do primeiro horário: 17
# Digite os minutos do primeiro horário: 00
# Digite a hora do segundo horário: 19
# Digite os minutos do segundo horário: 5
# O jogo teve no total 125 minutos.

# %% [markdown]
# ### 9. (Função sem retorno sem parâmetro) Faça uma função/método que leia cinco valores inteiros, determine e mostre o maior e o menor deles. Não pode usar vetor e função pronta da linguagem Python.

# %%
def maiorMenor():
    for i in range(5):
        numero = int(input("Digite o número: "))
        if i == 0:
            maior = numero
            menor = numero
        if numero > maior:
            maior = numero
        if numero < menor:
            menor = numero
    print(f"Menor número: {menor}\nMaior número: {maior}")

def main():
    maiorMenor()

main()
# Out:
# Digite o número: 5
# Digite o número: 3
# Digite o número: 1
# Digite o número: 4
# Digite o número: 2
# Menor: 1
# Maior: 5

# %% [markdown]
# ### 10. (Função sem retorno sem parâmetro) Faça uma função/método que leia um valor inteiro e positivo N e mostre o valor de S, obtido pelo seguinte cálculo:
# ###S = 1  +  1/1!  +  1/2!  +  1/3!  + ... +  1/N!
#
# Observvação: Não pode usar vetor e função pronta da linguagem Python.

# %%
# Digite seu código aqui.
# S = 1
# S = 1 + 1 + 1/2! + 1/3 + 1/4!
# S = 1 + 1 + 0.5 + 0.16 + 0.041
# S = 2.66 + 0.041
# 3! = 3 * 2 * 1 = 6
# 4! = 1 * 2 * 3 * 4 = 24    1/4!   1/24  = 0.041

# N = int(input('Informe o valor de N termos: '))
def calcula():
    f = 0
    n = int(input("Informe o valor de N termos: "))
    for n in range(1,n+2):
        fat = 1
        i = 2
        while i <= n:
            fat = fat * i
            i = i + 1
        s = float((n / fat))
        print(s)
        f += s
    print(f"Resultado: {f}")
def main():
    calcula()

main()
# Out:
# Informe o valor de N termos: 4
# 1.0
# 1.0
# 0.5
# 0.16666666666666666
# 0.041666666666666664
# Resultado: 2.708333333333333
