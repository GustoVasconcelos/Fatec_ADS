# %% [markdown]
# ##**P2 - 1º. semestre/2023 -   Término: 11:00**
# ## É uma prova de consulta ao seu material.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **NO DIA SEGUINTE**
# ##**O exame P3**, ocorrerá **dia 22/06** no **horário normal de aula**.
# ##***--------> A partir do momento que encerrar o prazo de responder (implementar) as questões da prova, o aluno ---- está PROÍBIDO ---- de realizar qualquer alteração no arquivo da prova. Qualquer alteração fica registrada na plataforma do Classroom/Collab <--------***
# ##O aluno tem que ter **12 pontos** na soma da P1 com a P2 para ser aprovado.
#
# ##A nota estará registrada no SIGA.
# ##A partir da próxima semana não conta mais presenças, ou seja, não farei mais chamada, mas o aluno se quiser ver a correção da prova, ou tirar dúvidas, pode vir a aula.
#
# ##**Sempre leiam** seus e-mails do @fatec.sp.gov.br e o Teams, pois é o nosso meio de comunicação com os alunos.
#
# ##Fiquem atentos a **data de REMATRÍCULA**, a secretaria informará.
#
# #**Boas férias!**......................................................

# %% [markdown]
# ###**1**.  [1,0 pontos] Em Python crie um programa que calcule e apresente o total de saldos cashback (float) de alguns clientes, mas não é informada a quantidade de clientes, então use como critério de parada (condição da estrutura de repetição, digitar zero no saldo cashback para sair).

# %%
saldos_cashback = 0
cashback = float(input("Digite o valor de cashback do cliente ou digite 0 (zero) para sair: "))
while cashback > 0:
    saldos_cashback += cashback
    cashback = float(input("Digite o valor de cashback do cliente ou digite 0 (zero) para sair: "))
if saldos_cashback == 0:
    print('Não foi informado nenhum saldo de cashback.')
else:
    print(f'A soma dos saldos de cashback dos cliente é: R${saldos_cashback:.2f}')
# Out:
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 130
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 140
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 150
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 160
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 170
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 180
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 190
# Digite o valor de cashback do cliente ou digite 0 (zero) para sair: 0
# A soma dos saldos de cashback dos cliente é: R$1120.00

# %% [markdown]
# ###**2**. [4,0 pontos] Em Python crie um programa que leia/armazene em um vetor 5 nomes de clientes, em outro vetor leia/armazene 5 valores/float de cashback e num terceiro vetor leia/armazene 5 valores que corresponam as compras que cada um realizou.
# ###No momento da compra, verifique se o saldo cashback do cliente é o suficiente para pagar a compra realizada, se sim subtraia do cashback o valor da compra realizada, caso não tenha, mostre a frase "Não há valor de cashback suficiente para pagamento desta compra."
# ###Ao final, mostre o vetor nome de clientes, o vetor saldo cashback e o vetor compras.

# %%
vet_nome, vet_cashback, vet_compra = [], [], []
for i in range(5):
    vet_nome.append(input("Digite o nome do cliente: "))
for i in range(5):
    vet_cashback.append(float(input(f"Digite o valor de cashback do cliente {vet_nome[i]}: ")))
for i in range(5):
    vet_compra.append(float(input(f"Digite o valor da compra do cliente {vet_nome[i]}: ")))
    if vet_compra[i] > vet_cashback[i]:
        print('Não há saldo suficiente de cashback para realizar esta compra!')
    if vet_compra[i] <= vet_cashback[i]:
        vet_cashback[i] -= vet_compra[i]
print(f'{vet_nome}\n{vet_cashback}\n{vet_compra}')
# Out:
# Digite o nome do cliente: Augusto
# Digite o nome do cliente: Bruno
# Digite o nome do cliente: Diogo
# Digite o nome do cliente: Thalia
# Digite o nome do cliente: Rosana
# Digite o valor de cashback do cliente Augusto: 500
# Digite o valor de cashback do cliente Bruno: 400
# Digite o valor de cashback do cliente Diogo: 300
# Digite o valor de cashback do cliente Thalia: 200
# Digite o valor de cashback do cliente Rosana: 600
# Digite o valor da compra do cliente Augusto: 499
# Digite o valor da compra do cliente Bruno: 401
# Não há saldo suficiente de cashback para realizar esta compra!
# Digite o valor da compra do cliente Diogo: 300
# Digite o valor da compra do cliente Thalia: 200
# Digite o valor da compra do cliente Rosana: 498
# ['Augusto', 'Bruno', 'Diogo', 'Thalia', 'Rosana']
# [1.0, 400.0, 0.0, 0.0, 102.0]
# [499.0, 401.0, 300.0, 200.0, 498.0]

# %% [markdown]
# ###**3**. [2,0 pontos] Em Python crie um programa que leia/armazene em uma matriz 3x3 valores inteiros, calcule e apresente a soma dos elementos da diagonal principal.

# %%
matriz = []
soma = 0
for lin in range(3):
    linha = []
    for col in range(3):
        linha.append(int(input("Digite um valor: ")))
    matriz.append(linha)
for lin in range(len(matriz)):
    for col in range(len(matriz)):
        if lin == col:
            soma += matriz[lin][col]
print(f'A soma dos elementos da diagonal principal é: {soma}')
# Out:
# Digite um valor: 2
# Digite um valor: 3
# Digite um valor: 4
# Digite um valor: 5
# Digite um valor: 2
# Digite um valor: 6
# Digite um valor: 7
# Digite um valor: 8
# Digite um valor: 2
# A soma dos elementos da diagonal principal é: 6
