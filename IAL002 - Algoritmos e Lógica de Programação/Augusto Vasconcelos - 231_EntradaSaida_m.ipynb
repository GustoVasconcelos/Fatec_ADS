# %% [markdown]
# # Exercícios para construir programas com ENTRADA, PROCESSAMENTO e SAÍDA

# %%
n1 = 7090
n2 = 3400
resultado_da_multiplicacao = n1 * n2
resultado_da_multiplicacao
# Out:
# 24106000

# %%
numero = float(input('Digite uma número: '))
type(numero)
print(numero)
# Out:
# Digite uma número: 7.5
# 7.5

# %% [markdown]
# ### 1. Faça um programa que leia um número, multiplique ele por 2 e apresente o resultado.
#       LEIA numero
#       resultado = numero * 2
#       ESCREVA resultado

# %%
# 1º passo - identificar a(s) entrada(s) - variável número
print('*** PROGRAMA PARA MULTIPLICAR UM NÚMERO POR 2 ***')
numero = int(input('Informe um valor......: '))

# 2º passo - identificar o processamento/cálculo
resultado = numero * 2

# 3º passo - apresentar a(s) variáveis que foram calculadas
print('A multiplicação é=',resultado)
# Out:
# *** PROGRAMA PARA MULTIPLICAR UM NÚMERO POR 2 ***
# Informe um valor......: 90
# A multiplicação é= 180

# %% [markdown]
# ### 2. Faça um programa que:
# * receba três números inteiros
# * calcule e mostre a soma desses números.

# %%
print('*** PROGRAMA PARA SOMAR TRÊS NÚMEROS ***')
n1 = int(input('Digite o primeiro número: '))
n2 = int(input('Digite o segundo número: '))
n3 = int(input('Digite o terceiro número: '))
resultado = n1 + n2 + n3
print('O restultado da soma dos números é:',resultado)
# Out:
# *** PROGRAMA PARA SOMAR TRÊS NÚMEROS ***
# Digite o primeiro número: 1
# Digite o segundo número: 2
# Digite o terceiro número: 3
# O restultado da soma dos números é: 6

# %% [markdown]
# ### 3. Faça um programa que receba três notas, calcule e mostre a média aritmética.

# %%
print('*** PROGRAMA PARA DAR A MÉDIA DAS NOTAS ***')
nota1 = float(input('Digite a primeira nota: '))
nota2 = float(input('Digite a segunda nota: '))
nota3 = float(input('Digite a terceira nota: '))
media = (nota1 + nota2 + nota3) / 3
print(f'A média das notas é: {media:.2f}')
# Out:
# *** PROGRAMA PARA DAR A MÉDIA DAS NOTAS ***
# Digite a primeira nota: 1
# Digite a segunda nota: 3
# Digite a terceira nota: 6
# A média das notas é: 3.33

# %% [markdown]
# ### 4. Faça um programa que:
# * receba o salário de um funcionário
# * calcule e mostre o novo salário, sabendo-se que este sofreu um aumento de 25%.
#
#       LEIA salario
#       novoSalario = salario + (salario * 25 / 100)
#       ESCREVA novoSalario

# %%
print('*** PROGRAMA PARA CALCULAR O AUMENTOS DOS FUNCIONÁRIOS ***')
salario = float(input('Digite o salário do funcionário: '))
novo_salario = salario + (salario * 25 / 100)
print(f'O novo salário do funcionário é: R${novo_salario:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O AUMENTOS DOS FUNCIONÁRIOS ***
# Digite o salário do funcionário: 1000
# O novo salário do funcionário é: R$1250.00

# %% [markdown]
# ### 5. Faça um programa que receba o salário de um funcionário e o percentual de aumento, calcule e mostre o valor do aumento e o novo salário.

# %%
print('*** PROGRAMA PARA CALCULAR O AUMENTOS DOS FUNCIONÁRIOS ***')
salario = float(input('Digite o salário do funcionário: '))
percent_aumento = float(input('Digite o percentual do aumento: '))
aumento = salario * percent_aumento / 100
novo_salario = salario + aumento
print(f'O valor do aumento é: R${aumento:.2f}')
print(f'O novo salário do funcionário é: R${novo_salario:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O AUMENTOS DOS FUNCIONÁRIOS ***
# Digite o salário do funcionário: 1320
# Digite o percentual do aumento: 6.4
# O valor do aumento é: R$84.48
# O novo salário do funcionário é: R$1404.48

# %% [markdown]
# ### 6. Faça um programa que receba o salário base de um funcionário, calcule e mostre o salário a receber, sabendo-se que o funcionário tem gratificação de 5% sobre o salário base e **paga imposto** de 7% também sobre o salário base.

# %%
print('*** PROGRAMA PARA CALCULAR O SALARIO DO FUNCIONARIO JA DESCONTANDO O IMPOSTO A SER PAGO ***')
salario_base = float(input('Digite o salário base do funcionário: '))
novo_salario = salario_base + (salario_base * 5 / 100) - (salario_base * 7 / 100)
print(f'O novo salário do funcionário já descontando o imposto de 7% é: R${novo_salario:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O SALARIO DO FUNCIONARIO JA DESCONTANDO O IMPOSTO A SER PAGO ***
# Digite o salário base do funcionário: 1500
# O novo salário do funcionário já descontando o imposto de 7% é: R$1470.00

# %% [markdown]
# ### 7. Faça um programa que receba o salário base de um funcionário, calcule e mostre seu salário a receber, sabendo-se que o funcionário tem gratificação de 50,00 sobre o salário base e **paga** imposto que deve ser lido e é aplicado sobre o salário base.
#
#     LEIA salario, perImposto
#     imposto = salario * perImposto / 100
#     salario_a_receber = salario + 50 - imposto
#     ESCREVA salario_a_receber

# %%
print('*** PROGRAMA PARA CALCULAR O SALARIO DO FUNCIONÁRIO JA DESCONTANDO O VALOR DO IMPOSTO A SER PAGO ***')
salario = float(input('Digite o valor do salário do funcionário: '))
perImposto = float(input('Digite o percentual de imposto: '))
salario_a_receber = salario + 50 - (salario * perImposto / 100)
print(f'O salário do funcionário a receber é: R${salario_a_receber:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O SALARIO DO FUNCIONÁRIO JA DESCONTANDO O VALOR DO IMPOSTO A SER PAGO ***
# Digite o valor do salário do funcionário: 1000
# Digite o percentual de imposto: 8
# O salário do funcionário a receber é: R$970.00

# %% [markdown]
# ### 8. Faça um programa que receba o valor de um depósito e o valor da taxa de juros, calcule e mostre o valor do rendimento e o valor total depois do rendimento de um mês.
#     rendimento = deposito * taxa / 100
#     total = deposito + rendimento

# %%
print("*** PROGRAMA QUE CALCULA O VALOR DO RENDIMENTO DE UM DEPOSITO APÓS 1 MÊS ***")
deposito = float(input('Digite o valor do depósito: '))
taxa = float(input('Digite a porcentagem da taxa: '))
rendimento = deposito * taxa / 100
total_rendimento = deposito + rendimento
print(f'O valor do rendimento é: R${rendimento:.2f}')
print(f'O valor do rendimento total em 30 dias é: R${total_rendimento:.2f}')
# Out:
# *** PROGRAMA QUE CALCULA O VALOR DO RENDIMENTO DE UM DEPOSITO APÓS 1 MÊS ***
# Digite o valor do depósito: 1000
# Digite a porcentagem da taxa: 5
# O valor do rendimento é: R$50.00
# O valor do rendimento total em 30 dias é: R$1050.00

# %% [markdown]
# ### 9. Faça um programa que calcule e mostre a área de um triângulo. Sabe-se que: Área = (base * altura) / 2.

# %%
print('*** PROGRAMA QUE CALCULA A ÁREA DE UM TRIÂNGULO ***')
base = float(input('Digite o valor da base do triângulo: '))
altura = float(input('Digite o valor da altura do triângulo: '))
area = (base * altura) / 2
print(f'A área do triângulo é: {area:.2f}')
# Out:
# *** PROGRAMA QUE CALCULA A ÁREA DE UM TRIÂNGULO ***
# Digite o valor da base do triângulo: 8
# Digite o valor da altura do triângulo: 4
# A área do triângulo é: 16.00

# %% [markdown]
# ### 10. Faça um programa que calcule e mostre a área de um círculo. Sabe-se que:
#     area = pi * raio² ou
#     area = 3.1415 * raio²

# %%
print('*** PROGRAMA PARA CALCULAR A ÁREA DE UM CIRCULO ***')
raio = float(input('Digite o raio do círculo: '))
area = 3.1415 * raio ** 2
print(f'O valor da área do círculo é {area:.2f} metros quadrados.')
# Out:
# *** PROGRAMA PARA CALCULAR A ÁREA DE UM CIRCULO ***
# Digite o raio do círculo: 38.7
# O valor da área do círculo é 4704.99 metros quadrados.

# %% [markdown]
# ### 11. Faça um programa que receba um número, calcule e mostre:
# * O número digitado ao quadrado
# * O número digitado ao cubo
# * A raiz do número digitado
# * A raiz cúbica do número digitado
#
#       LEIA numero
#       quadrado = numero ** 2
#       cubo = numero ** 3
#       raiz_quadrada = numero ** (½) (meio, ou 0.5)
#       raiz_cubica = numero ** (⅓) (um terço, ou 0.33)
#       ESCREVA quadrado, cubo, raiz_quadrada, raiz_cubica
#
#
#       raiz_quadrada = numero ** (1/2) ou
#       raiz_quadrada = numero ** 0.5

# %%
print('*** PROGRAMA PARA CALCULAR POTÊNCIAS E RAIZES DE UM NÚMERO ***')
numero = float(input('Digite um número para calcular: '))
quadrado = numero ** 2
cubo = numero ** 3
raiz_quadrada = numero ** 0.5
raiz_cubica = numero ** 0.33
print(f'O numéro ao quadrado é: {quadrado:.2f}\nO número ao cubo é: {cubo:.2f}\nA raiz quadrada é: {raiz_quadrada:.2f}\nA raiz cubica é: {raiz_cubica:.4f}')
# Out:
# *** PROGRAMA PARA CALCULAR POTÊNCIAS E RAIZES DE UM NÚMERO ***
# Digite um número para calcular: 4
# O numéro ao quadrado é: 16.00
# O número ao cubo é: 64.00
# A raiz quadrada é: 2.00
# A raiz cubica é: 1.5801

# %% [markdown]
# ### 12. Faça um programa que receba dois números, calcule e mostre um elevado ao outro. Use os caracteres **

# %%
print('*** PROGRAMA PARA CALCULAR UM NÚMERO ELEVADO AO OUTRO ***')
num1 = float(input('Digite o primeiro número: '))
num2 = float(input('Digite o segundo número: '))
num1_elev = num1 ** num2
num2_elev = num2 ** num1
print(f'O {num1} elevado ao {num2} é: {num1_elev}\nO {num2} elevado ao {num1} é: {num2_elev}')
# Out:
# *** PROGRAMA PARA CALCULAR UM NÚMERO ELEVADO AO OUTRO ***
# Digite o primeiro número: 9
# Digite o segundo número: 8
# O 9.0 elevado ao 8.0 é: 43046721.0
# O 8.0 elevado ao 9.0 é: 134217728.0

# %% [markdown]
# ### 13. Sabe-se que:
#
# * pé = 12 polegadas
# * 1 jarda = 3 pés
# * 1 milha = 1760 jarda
#
# Faça um programa que receba uma medida em pés, faça as conversões a seguir e mostre os resultados.
#
# * Polegadas;
# * Jardas;
# * Milhas.
#
#       LEIA pes
#       polegadas = pes * 12
#       jardas = pes / 3
#       milhas = jardas / 1760
#       ESCREVA polegadas, jardas, milhas

# %%
print('*** PROGRAMA PARA CALCULAR JARDAS, MILHAS E POLEGADAS ***')
pes = float(input('Digite um numero em pés: '))
polegadas = pes * 12
jardas = pes / 3
milhas = jardas / 1760
print(f'Polegadas:{polegadas:.2f}\nJardas:{jardas:.2f}\nMilhas:{milhas:.4f}')
# Out:
# *** PROGRAMA PARA CALCULAR JARDAS, MILHAS E POLEGADAS ***
# Digite um numero em pés: 12
# Polegadas:144.00
# Jardas:4.00
# Milhas:0.0023

# %% [markdown]
# ### 14. Faça um programa que receba o ano de nascimento de uma pessoa e o ano atual, calcule e mostre:
# * a idade atual da pessoa;
# * quantos anos ela terá em 2050.

# %%
print('*** PROGRAMA PARA CALCULAR A IDADE DE UMA PESSOA ***')
ano_nasc = int(input('Digite o ano de nascinemto: '))
ano_atual = int(input('Digite o ano atual: '))
idade_atual = ano_atual - ano_nasc
idade_fut = 2050 - ano_nasc
print(f'A pessoa tem {idade_atual} anos. Em 2050 ela terá {idade_fut} anos.')
# Out:
# *** PROGRAMA PARA CALCULAR A IDADE DE UMA PESSOA ***
# Digite o ano de nascinemto: 1989
# Digite o ano atual: 2023
# A pessoa tem 34 anos. Em 2050 ela terá 61 anos.

# %% [markdown]
# #### 15. O custo ao consumidor de um carro novo é a soma do preço de fábrica com o percentual de lucro do distribuidor e dos impostos aplicados ao preço de fábrica. Faça um programa que receba o preço de fábrica de um veículo, o percentual de lucro do distribuidor e o percentual de impostos, calcule e mostre:
# * o valor correspondente ao lucro do distribuidor;
# * o valor correspondente aos impostos;
# * o preço final do veículo.
#         LEIA preco_fabrica
#         LEIA percentual_lucro_distribuidor
#         LEIA percentual_imposto
#         lucro_distribuidor = preco_fabrica * percentual_lucro_distribuidor / 100
#         valor_imposto = preco_fabrica * percentual_imposto / 100
#         preco_final = preco_fabrica + lucro_distribuidor + valor_imposto
#         ESCREVA lucro_distribuidor
#         ESCREVA valor_imposto
#         ESCREVA preco_final

# %%
print('*** PROGRAMA PARA CALCULAR O VALOR DE VENDA DE VEICULOS ***')
preco_fabrica = float(input('Digite o valor de fabrica do veiculo: '))
perc_lucro_dist = float(input('Digite o percentual do lucro do distribuidor: '))
perc_imposto = float(input('Digite o percentual de imposto: '))
lucro_dist = preco_fabrica * perc_lucro_dist / 100
valor_imposto = preco_fabrica * perc_imposto / 100
preco_final = preco_fabrica + lucro_dist + valor_imposto
print(f'O valor do lucro do distribuidor: R${lucro_dist:.2f}\nO valor dos impostos: R${valor_imposto:.2f}\nO valor do preço final do veiculo: R${preco_final:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O VALOR DE VENDA DE VEICULOS ***
# Digite o valor de fabrica do veiculo: 25000
# Digite o percentual do lucro do distribuidor: 20
# Digite o percentual de imposto: 10
# O valor do lucro do distribuidor: R$5000.00
# O valor dos impostos: R$2500.00
# O valor do preço final do veiculo: R$32500.00

# %% [markdown]
# ### 16. Faça um programa que receba o número de horas trabalhadas e o valor do salário mínimo, calcule e mostre o salário a receber, seguindo estas regras:
# * a hora trabalhada vale a metade do salário mínimo.
# * o salário bruto equivale ao número de horas trabalhadas multiplicado pelo valor da hora trabalhada.
# * o imposto equivale a 3% do salário bruto.
# * o salário a receber equivale ao salário bruto menos o imposto.
#       LEIA qtde_horas_trabalhadas
#       LEIA valor_salario_minimo
#       valor_hora_trabalhada = valor_salario_minimo / 2
#       valor_salario_bruto = valor_hora_trabalhada * qtde_horas_trabalhadas
#       imposto = valor_salario_bruto * 3 / 100
#       valor_salario_liquido =  valor_salario_bruto - imposto
#       ESCREVA valor_salario_liquido

# %%
print('*** PROGRAMA PARA CALCULAR O SALARIO/HORAS TRABALHADAS DO FUNCIONARIO ***')
qtde_horas_trab = float(input('Digite a quantidade de horas trabalhadas: '))
valor_salario_min = float(input('Digite o valor do salário mínimo: '))
valor_hora_trab = valor_salario_min / 2
valor_salario_bruto = valor_hora_trab * qtde_horas_trab
imposto = valor_salario_bruto * 3 / 100
valor_salario_liq = valor_salario_bruto - imposto
print(f'O valor do salário a receber é: R${valor_salario_liq:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O SALARIO/HORAS TRABALHADAS DO FUNCIONARIO ***
# Digite a quantidade de horas trabalhadas: 4
# Digite o valor do salário mínimo: 1320
# O valor do salário a receber é: R$2560.80

# %% [markdown]
# ### 17. Um trabalhador recebeu seu salário e o depositou em sua conta bancária. Esse trabalhador emitiu dois cheques e agora deseja saber seu saldo atual. O banco criou uma taxa para a operação bancária de retirada que tem que pagar um imposto de 0.38% e o saldo inicial da conta está zerado.
#
#       LEIA salario
#       LEIA valor_cheque1
#       LEIA valor_cheque2
#       imposto_cheque1 = valor_cheque1 * 0.38 / 100
#       saque1 = valor_cheque1 + imposto_cheque1
#       imposto_cheque2 = valor_cheque2 * 0.38 / 100
#       saque2 = valor_cheque2 + imposto_cheque2
#       saldo = salario - saque1 - saque2
#       ESCREVA saldo

# %%
print('*** PROGRAMA PARA CALCULAR O SALDO DA CONTA ***')
salario = float(input('Digite o valor recebido do salario: '))
valor_cheque1 = float(input('Digite o valor do primeiro cheque emitido: '))
valor_cheque2 = float(input('Digite o valor do segundo cheque emitido: '))
imposto_cheque1 = valor_cheque1 * 0.38 / 100
saque1 = valor_cheque1 + imposto_cheque1
imposto_cheque2 = valor_cheque2 * 0.38 / 100
saque2 = valor_cheque2 + imposto_cheque2
saldo = salario - saque1 - saque2
print(f'O saldo da sua conta é: R${saldo:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR O SALDO DA CONTA ***
# Digite o valor recebido do salario: 2000
# Digite o valor do primeiro cheque emitido: 300
# Digite o valor do segundo cheque emitido: 400
# O saldo da sua conta é: R$1297.34

# %% [markdown]
# ### 18. Faça um programa que receba a medida do ângulo (em graus) formado por uma escada apoiada no chão e encostada na parede e a altura da parede onde está a ponta da escada. Calcule e mostre a medida dessa escada. Observação: as funções trigonométricas implementadas nas linguagens de programação trabalham com medidas de ângulos em radianos.
#       LEIA angulo
#       LEIA altura
#       import math # carrega a biblioteca matemática
#       radiano = angulo * math.pi / 180
#       escada = altura / math.sin(radiano)
#       ESCREVA escada
# **Observação**: Para usar seno em Python, deve-se usar esta linha de código **import math** e esta, no cálculo, **math.sin(numero)**
#
# **import math**
#
# escada = altura / **math.sin**(numero)

# %%
import math # carrega a biblioteca matematica
print('*** PROGRAMA PARA CALCULAR A MEDIDA DE UMA ESCADA ***')
angulo = float(input('Digite a medida do ângulo (em graus): '))
altura = float(input('Digite a altura da parede: '))
radiano = angulo * math.pi / 180
escada = altura / math.sin(radiano)
print(f'A medida da escada é {escada:.2f} metros.')
# Out:
# *** PROGRAMA PARA CALCULAR A MEDIDA DE UMA ESCADA ***
# Digite a medida do ângulo (em graus): 45
# Digite a altura da parede: 5
# A medida da escada é 7.07 metros.

# %% [markdown]
# ###19. Sabe-se que o quilowatt de energia custa um quinto do salário mínimo. Faça um programa que receba o valor do salário mínimo e a quantidade de quilowatts consumida por uma residência. Calcule e mostre:
#
#
# * o valor de cada quilowatt;
# * o valor a ser pago por essa residência;
# * o valor a ser pago com desconto de 15%.
#       LEIA valor_salario
#       LEIA qtde_quilowatt
#       valor_quilowatt = valor_salario / 5
#       valor_em_reais = valor_quilowatt * qtde_quilowatt
#       valor_descontado = valor_em_reais * 15 / 100
#       valor_com_desconto =  valor_em_reais − valor_descontado
#       ESCREVA valor_quilowatt
#       ESCREVA valor_em_reais
#       ESCREVA valor_com_desconto

# %%
print('*** PROGRAMA PARA CALCULAR A QUANTIDADE GASTA DE QUILOWATT EM UMA CASA ***')
valor_salario = float(input('Digite o seu salário: '))
qtde_quilowatt = float(input('Digite a quantidade gasta de quilowatt: '))
valor_quilowatt = valor_salario / 5
valor_em_reais = valor_quilowatt * qtde_quilowatt
valor_descontado = valor_em_reais * 15 / 100
valor_com_desconto = valor_em_reais - valor_descontado
print(f'O valor de cada quilowatt é: R${valor_quilowatt:.2f}\nO valor a ser pago é: R${valor_em_reais:.2f}\nO valor da conta com 15% de desconto é: R${valor_com_desconto:.2f}')
# Out:
# *** PROGRAMA PARA CALCULAR A QUANTIDADE GASTA DE QUILOWATT EM UMA CASA ***
# Digite o seu salário: 1320
# Digite a quantidade gasta de quilowatt: 2
# O valor de cada quilowatt é: R$264.00
# O valor a ser pago é: R$528.00
# O valor da conta com 15% de desconto é: R$448.80

# %% [markdown]
# ### 20. Faça um programa que receba um número real, encontre e mostre:
#
# * a parte inteira desse número;
# * a parte fracionária desse número;
# * o arredondamento desse número.
#
#       LEIA numero
#       parte_inteira = numero // 1
#       parte_fracionaria = numero - parte_inteira
#       numero_arredondado = round (numero)
#       ESCREVA parte_inteira
#       ESCREVA parte_fracionaria
#       ESCREVA numero_arredondado
#
# **Observação**: Para arredondar um número em Python, usa-se a função **round(numero)**, onde se o número real/float estiver em igual distância entre o inteiro de cima e o inteiro de baixo, esta função arredonda para o número mais próximo.

# %%
print('*** PROGRAMA PARA CALCULAR PARTES DE UM NUMERO REAL ***')
numero = float(input('Digite um número real: '))
pt_int = numero // 1
pt_frac = numero - pt_int
num_arre = round(numero)
print(f'A parte inteira desse número é: {pt_int:.0f}\nA parte fracionária desse número é: {pt_frac:.1f}\nO arredondamento desse número é: {num_arre}')
# Out:
# *** PROGRAMA PARA CALCULAR PARTES DE UM NUMERO REAL ***
# Digite um número real: 2.8
# A parte inteira desse número é: 2
# A parte fracionária desse número é: 0.8
# O arredondamento desse número é: 3

# %% [markdown]
# ### 21. Faça um programa que receba uma hora formada por hora e minutos (um número real), calcule e mostre a hora digitada apenas em minutos. Lembre-se de que:
# * para quatro e meia, deve-se digitar 4.30;
# * os minutos vão de 0 a 59.
#       LEIA hora
#       h = pegar a parte inteira da variável hora
#       minutos = hora − h
#       conversao = (h * 60) + (minutos * 100)
#       ESCREVA conversao

# %%
print('*** PROGRAMA PARA CALCULAR MINUTOS A PARTIR DE UM NUMERO REAL ***')
hora = float(input('Digite uma hora formada por um numero real: '))
h = hora // 1
minutos = hora - h
conversao = (h * 60) + (minutos * 100)
print(f'A quantidade de minutos é {conversao}')
# Out:
# *** PROGRAMA PARA CALCULAR MINUTOS A PARTIR DE UM NUMERO REAL ***
# Digite uma hora formada por um numero real: 2.59
# A quantidade de minutos é 179.0

# %% [markdown]
# ### 22. Faça um programa que receba o custo de um espetáculo teatral e o preço do convite desse espetáculo. Esse programa deverá calcular e mostrar a quantidade de convites que devem ser vendidos para que, pelo menos, o custo do espetáculo seja alcançado.

# %%
print('*** PROGRAMA PARA CALCULAR O CUSTO OPERACIONAL DE UM ESPETACULO TEATRAL ***')
custo_espetaculo = float(input('Digite o custo operacional do evento: '))
custo_convite = float(input('Digite o valor do convite do evento: '))
total = custo_espetaculo / custo_convite
print(f'Para que o evento se pague, será necessário vender {total:.0f} convites.')
# Out:
# *** PROGRAMA PARA CALCULAR O CUSTO OPERACIONAL DE UM ESPETACULO TEATRAL ***
