# %% [markdown]
# ### **EXERCÍCIOS DE ESTRUTURA DE REPETIÇÃO SEM CONTADOR**

# %% [markdown]
# ###1. Construir um algoritmo para calcular e apresentar o total de salários pagos de funcionários, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no salário para sair.

# %%
soma_salario = 0
salario = float(input('Digite o salario do funcionário ou digite 0 para sair: '))
while salario > 0:
    soma_salario = soma_salario + salario
    salario = float(input('Digite o salario do funcionário ou digite 0 para sair: '))
print(f'A soma dos salários dos funcionários é de R$ {soma_salario:.2f}')
# Out:
# Digite o salario do funcionário ou digite 0 para sair: 2000
# Digite o salario do funcionário ou digite 0 para sair: 2000
# Digite o salario do funcionário ou digite 0 para sair: 2000
# Digite o salario do funcionário ou digite 0 para sair: 0
# A soma dos salários dos funcionários é de R$ 6000.00

# %%
soma_salario = 0 # GAMBIARRA ...
salario = 1
while salario > 0:
    salario = float(input('Digite o salario do funcionário ou digite 0 para sair: '))
    if salario > 0:
        soma_salario = soma_salario + salario
print(f'A soma dos salários dos funcionários é de R$ {soma_salario:.2f}')
# Out:
# Digite o salario do funcionário ou digite 0 para sair: 1000
# Digite o salario do funcionário ou digite 0 para sair: 1000
# Digite o salario do funcionário ou digite 0 para sair: 1000
# Digite o salario do funcionário ou digite 0 para sair: -10
# A soma dos salários dos funcionários é de R$ 3000.00

# %% [markdown]
# ###2. Faça um programa que receba a altura de 5 pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes.

# %%
for pessoas in range(5):
    altura = float(input('Informe a altura: '))
    nome = input('Informe o nome: ')
    # dica de implementação, inicializar as variáveis de menor e maior
    # valor dentro do laço de repetição, quando você souber, quantas
    # vezes repete
    if pessoas == 0:
        alto = altura
        nomea = nome
        baixo = altura
        nomeb = nome
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
print(nomea,'é mais alto, com',alto,'metros')
print(nomeb,'é mais baixo, com',baixo,'metros')
# Out:
# Informe a altura: 1.78
# Informe o nome: Lucas
# Informe a altura: 1.8
# Informe o nome: Andres
# Informe a altura: 1.75
# Informe o nome: Felipe
# Informe a altura: 1.8
# Informe o nome: Edivaldo
# Informe a altura: 1.65
# Informe o nome: Patricia
# Edivaldo é mais alto, com 1.8 metros
# Patricia é mais baixo, com 1.65 metros

# %% [markdown]
# ###3. Faça um programa que receba a altura de várias pessoas. Encontre e apresente a altura da pessoa mais alta e da mais baixa e seus respectivos nomes. Para encerrar a entrada de dados, zero na altura, mas esta não poderá ser considerada como resposta da altura da pessoa mais baixa.

# %%
alto = 0
baixo = 3
pessoas = 0
altura = float(input('Digite a altura da pessoa, ou digite 0 para sair: '))
while altura > 0:
    nome = input('Digite o nome da pessoa:')
    if altura >= alto:
        alto = altura
        nomea = nome
    elif altura <= baixo:
        baixo = altura
        nomeb = nome
    pessoas = pessoas + 1
    altura = float(input('Digite a altura da pessoa, ou digite 0 para sair: '))
if pessoas >= 2:
    print(f'{nomea} é mais alto, com {alto} metros\n{nomeb} é mais baixo, com {baixo} metros')
else:
    print('Digite a altura e nome de 2 pessoas ou mais para comparação.')
# Out:
# Digite a altura da pessoa, ou digite 0 para sair: 1.68
# Digite o nome da pessoa:Rosana
# Digite a altura da pessoa, ou digite 0 para sair: 1.5
# Digite o nome da pessoa:Thalia
# Digite a altura da pessoa, ou digite 0 para sair: 1.76
# Digite o nome da pessoa:Augusto
# Digite a altura da pessoa, ou digite 0 para sair: 1.8
# Digite o nome da pessoa:Diogo
# Digite a altura da pessoa, ou digite 0 para sair: 0
# Diogo é mais alto, com 1.8 metros
# Thalia é mais baixo, com 1.5 metros

# %% [markdown]
# ###4. Faça um programa que receba a idade e a altura de várias pessoas. Calcule e exiba a média das alturas das pessoas com mais de 20 anos. Para encerrar a entrada de dados, digite uma idade negativa ou igual a zero.

# %%
soma_alturas, pessoas = 0, 0
idade = int(input('Digite sua idade, ou digite um valor menor ou igual a 0 para sair...: '))
while idade > 0:
    altura = float(input('Digite a altura: '))
    if idade > 20:
        soma_alturas = soma_alturas + altura
        pessoas = pessoas + 1
    idade = int(input('Digite sua idade, ou digite um valor menor ou igual a 0 para sair: '))
if pessoas > 0:
    media_altura = soma_alturas / pessoas
    print(f'A média das alturas de pessoas ({pessoas}) com mais de 20 anos é {media_altura:.2f}')
# Out:
# Digite sua idade, ou digite um valor menor ou igual a 0 para sair...: 21
# Digite a altura: 1.8
# Digite sua idade, ou digite um valor menor ou igual a 0 para sair: 23
# Digite a altura: 1.8
# Digite sua idade, ou digite um valor menor ou igual a 0 para sair: 22
# Digite a altura: 1.8
# Digite sua idade, ou digite um valor menor ou igual a 0 para sair: 0
# A média das alturas de pessoas (3) com mais de 20 anos é 1.80

# %% [markdown]
# ###5. Construir um algoritmo para calcular e apresentar a idade atual de algumas pessoas em relação ao ano atual, mas não é informado a quantidade de pessoas, então use como critério de parada (condição da estrutura de repetição, digitar zero no ano de nascimento para sair.

# %%
nascimento = int(input('Digite o ano de nascimento...: '))
while nascimento > 0:
    idade = 2023 - nascimento
    print(f'A idade da pessoa é {idade} anos')
    nascimento = int(input('Digite o ano de nascimento: '))
# Out:
# Digite o ano de nascimento...: 1989
# A idade da pessoa é 34 anos
# Digite o ano de nascimento: 1995
# A idade da pessoa é 28 anos
# Digite o ano de nascimento: 2022
# A idade da pessoa é 1 anos
# Digite o ano de nascimento: 0

# %% [markdown]
# ###6. Faça um programa que receba um conjunto de valores inteiros, calcule e exiba o maior e o menor valor do conjunto.
#
#
# *   Para encerrar a entrada de dados, deve ser digitado o valor zero;
# *   Para valores negativos, deve ser enviada uma mensagem;
# *   Esses valores (zero e negativos) não entrarão na lógica de encontrar o maior e o menor valor.

# %%
maior, menor, cont = 0, 999999999999999, 0
valor = int(input('Digite um número...: '))
while valor != 0:
    if valor < 0:
        print('Valor negativo digitado.')
        valor = int(input('Digite um número: '))
    else:
        if valor > maior:
            maior = valor
        elif valor < menor:
            menor = valor
        cont = cont + 1
        valor = int(input('Digite um número: '))
if cont > 0:
    print(f'O maior número é {maior} e o menor número é {menor}.')
# Out:
# Digite um número...: -3
# Valor negativo digitado.
# Digite um número: 2
# Digite um número: 99
# Digite um número: 3
# Digite um número: 4
# Digite um número: 101
# Digite um número: 1
# Digite um número: -4
# Valor negativo digitado.
# Digite um número: 0
# O maior número é 101 e o menor número é 1.

# %% [markdown]
# ###7. No final do ano muitas pessoas compram presentes. Faça um programa que registre alguns dados das pessoas, usando como critério de parada a letra ‘n’, para a pergunta “Deseja cadastrar outro (‘s’/’n’)?”, para identificar o perfil dos compradores numa loja de roupas e apresente como resultado a:
# a)   Quantidade de mulheres e de homens;
#
# b)   Quantidade de mulheres e de homens abaixo e acima de 18 anos.

# %%
mulher, mulher_acima, mulher_abaixo, homem, homem_acima, homem_abaixo = 0, 0, 0, 0, 0, 0
resposta = input('Deseja cadastrar outro (s/n)?...: ')
while resposta == 's':
    sexo = input('Digite o sexo da pessoa (H/M): ')
    idade = int(input('Digite a idade da pessoa: '))
    if sexo == "H":
        homem = homem + 1
        if idade > 18:
            homem_acima = homem_acima + 1
        else:
            homem_abaixo = homem_abaixo + 1
    elif sexo == "M":
        mulher = mulher +1
        if idade > 18:
            mulher_acima = mulher_acima + 1
        else:
            mulher_abaixo = mulher_abaixo + 1
    resposta = input('Deseja cadastrar outro (s/n)?...: ')
if mulher > 0 or homem > 0:
    print('.'*50,f'\nQuantidade de Mulheres cadastradas: {mulher}\nQuantidade de Homens cadastrados: {homem}')
    print(f'Mulheres abaixo de 18 anos: {mulher_abaixo} - Mulheres acima de 18 anos: {mulher_acima}\nHomens abaixo de 18 anos: {homem_abaixo} - Homens acima de 18 anos: {homem_acima}')
# Out:
# Deseja cadastrar outro (s/n)?...: s
# Digite o sexo da pessoa (H/M): H
# Digite a idade da pessoa: 20
# Deseja cadastrar outro (s/n)?...: s
# Digite o sexo da pessoa (H/M): M
# Digite a idade da pessoa: 22
# Deseja cadastrar outro (s/n)?...: s
# Digite o sexo da pessoa (H/M): H
# Digite a idade da pessoa: 12
# Deseja cadastrar outro (s/n)?...: s
# Digite o sexo da pessoa (H/M): M
# Digite a idade da pessoa: 12
# Deseja cadastrar outro (s/n)?...: n
# ..................................................
# Quantidade de Mulheres cadastradas: 2
# Quantidade de Homem cadastrados: 2
# Mulheres abaixo de 18 anos: 1 - Mulheres acima de 18 anos: 1
# Homens abaixo de 18 anos: 1 - Homens acima de 18 anos: 1
