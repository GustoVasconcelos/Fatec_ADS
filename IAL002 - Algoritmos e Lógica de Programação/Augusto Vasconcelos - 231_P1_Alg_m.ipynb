# %% [markdown]
# ##**P1 - 1º. semestre/2023 -  Término: 11:00**
# ## É uma prova de consulta ao seu material (slides da disciplina de Algoritmo usadas na aula e lista de exercícios do Colab da aula) e vale 7 pontos.
# ## **Apenas verificarei** o desenvolvimento dos exercícios de cada aluno, **EM OUTRO DIA**.
#
# ##Caso entregue atrasado não será aceita a prova.
# ##Depois de terminada a prova, você NÃO PODE MAIS ALTERAR O ARQUIVO DELA, essa ação fica registrada e assim a prova será anulada.
# ##Na próxima aula será realizada a correção da prova.
# ##**Não é permitido o acesso a qualquer outro site/aplicativo para o desenvolvimento da prova, ou seja, apenas poderão estar abertas e visíveis as guias (no navegador de internet) do Classroom e Colab**
# ______________________________________________________

# %% [markdown]
# ##**1.** [1,5 pontos - Entrada, processamento e saída] Desenvolva um programa, utilizando a linguagem Python, que leia um valor float (x), calcule e apresente o valor de w seguindo a fórmula:
# ##w = 3x<sup>3</sup> - 2x<sup>2</sup> + 3x - 1

# %%
x = float(input("Digite o valor de X: "))
w = (3*(x**3)) - (2*(x**2)) + (3*(x-1))
print(f'O valor de w é {w}')
# Out:
# Digite o valor de X: 3
# O valor de w é 69.0

# %% [markdown]
# ##**2.** [2,5 pontos - Estrutura de decisão] Crie um programa, utilizando a linguagem Python, que receba três valores (obrigatoriamente maiores que zero), representando as medidas dos três lados de um triângulo. Determine se esses lados formam um triângulo e apresente a frase 'É um triângulo' ou 'Não é um triângulo'.
# ##Sabe-se que, para ser triângulo, a medida de um lado qualquer deve ser inferior ou igual à soma das medidas dos outros dois lados.

# %%
x = float(input('Digite o valor do primeiro lado do triângulo (x): '))
y = float(input('Digite o valor do segundo lado do triângulo (y): '))
z = float(input('Digite o valor do terceiro lado do triângulo (z): '))
if x > 0 and y > 0 and z > 0:
    if x <= y + z and y <= x + z and z <= x + y:
        print('É um triângulo!')
    else:
        print('Não é um triângulo!')
else:
    print('Foi digitado um valor menor ou igual a zero em um dos lados! Digite um valor maior que zero!')
# Out:
# Digite o valor do primeiro lado do triângulo (x): 5
# Digite o valor do segundo lado do triângulo (y): 7
# Digite o valor do terceiro lado do triângulo (z): 8
# É um triângulo!

# %% [markdown]
# ##**3.**  [3,0 pontos - Estrutura de repetição] O IPVA (Imposto sobre a Propriedade de Veículos Automotores), é um imposto que não possui valor único para todos os automóveis. O preço a ser pago varia de acordo com o valor venal do veículo e a alíquota do Estado onde ele foi registrado.
#
# ##A alíquota é uma porcentagem estipulada por cada Estado, que também pode variar de acordo com o tipo de combustível e categoria do veículo, veja a tabela das alíquotas médias de alguns estados, como exemplo:
#
# Estados	 |Alíquota
# ---------|---------
# São Paulo|	4%
# Paraná	 |3,5%
# Alagoas  |3%
# Bahia	 |2,5%
# Acre     |2%
#
# ##O cálculo é feito multiplicando o valor venal do veículo, estipulado pela tabela tabela FIPE, pela porcentagem da alíquota, neste caso utilize apenas a porcentagem do estado de São Paulo para o cálculo.
#
# ##Implemente uma programa, utilizando a linguagem Python, que receba o valor venal de 10 carros, calcule e apresente:
# * o IPVA de cada carro;
# * a média de IPVA de carros acima de R$ 80.000,00

# %%
print('*** Programa para calcular o valor do IPVA de acordo com o Estado. ***\n')
soma_ipva = 0
soma_carro = 0
for carros in range (10):
    valor_venal = float(input('Digite o valor venal do carro: '))
    while valor_venal <= 0:
        valor_venal = float(input('Valor venal do carro tem que ser maior que zero, digite o valor: '))
    estado = input('Estados Disponíveis para calculo:\nSão Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC\nDIgite a sigla do estado para calcular a aliquota: ')
    if estado == "SP" or estado == "sp":
        aliquota = 4/100
    elif estado == "PR" or estado == "pr":
        aliquota = 3.5/100
    elif estado == "AL" or estado == "al":
        aliquota = 3/100
    elif estado == "BA" or estado == "ba":
        aliquota = 2.5/100
    elif estado == "AC" or estado == "ac":
        aliquota = 2/100
    else:
        print("Estado não cadastrado, utilizando a menor aliquota (2%).")
        aliquota = 2/100
    valor_ipva = valor_venal * aliquota
    print(f'O valor de IPVA a ser pago do veiculo é R${valor_ipva:.2f}\n')
    if valor_venal > 80000:
        soma_ipva = soma_ipva + valor_ipva
        soma_carro = soma_carro + 1
if soma_carro > 0:
    media_ipva = soma_ipva / soma_carro
    print('.'*50,f'\nA média dos IPVAs dos carros acima de R$80.000,00 é de R${media_ipva:.2f}')
else:
    print('.'*50,'\nOs carros digitados tinham valor abaixo de R$80.000,00. Não foi calculado média de IPVA.')
# Out:
# *** Programa para calcular o valor do IPVA de acordo com o Estado. ***
#
# Digite o valor venal do carro: 90000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: SP
# O valor de IPVA a ser pago do veiculo é R$3600.00
#
# Digite o valor venal do carro: 91000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: pr
# O valor de IPVA a ser pago do veiculo é R$3185.00
#
# Digite o valor venal do carro: 92000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: al
# O valor de IPVA a ser pago do veiculo é R$2760.00
#
# Digite o valor venal do carro: 93000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: ba
# O valor de IPVA a ser pago do veiculo é R$2325.00
#
# Digite o valor venal do carro: 94000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: ac
# O valor de IPVA a ser pago do veiculo é R$1880.00
#
# Digite o valor venal do carro: 95000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: sp
# O valor de IPVA a ser pago do veiculo é R$3800.00
#
# Digite o valor venal do carro: 96000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: pr
# O valor de IPVA a ser pago do veiculo é R$3360.00
#
# Digite o valor venal do carro: 97000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: al
# O valor de IPVA a ser pago do veiculo é R$2910.00
#
# Digite o valor venal do carro: 98000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: ba
# O valor de IPVA a ser pago do veiculo é R$2450.00
#
# Digite o valor venal do carro: 99000
# Estados Disponíveis para calculo:
# São Paulo: SP || Paraná: PR || Alagoas: AL || Bahia: BA || Acre: AC
# DIgite a sigla do estado para calcular a aliquota: ac
# O valor de IPVA a ser pago do veiculo é R$1980.00
#
# ..................................................
# A média dos IPVAs dos carros acima de R$80.000,00 é de R$2825.00
